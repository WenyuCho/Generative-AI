# %% [markdown]
# <a href="https://colab.research.google.com/github/WenyuCho/Generative-AI/blob/main/Homework/GenAI_HW4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.Benchmarks : 茶文化的相關知識
#
# ### 先看結果 ( GPT4.0獲勝 )
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 2.選擇此主題原因 :
# ### 我對於茶領域的知識以及泡茶選茶的實踐，有累積很多經驗，除了從書上學習，也實際走訪許多茶廠，向第一線製茶人學習知識，泡茶的各種因素(水質、水溫、茶具材質、沖泡時間、不同茶種)都有多方嘗試以及歸納屬於自己的心得。
#
# # 3.Benchmarks 評斷標準 :
# ### 由於茶泡得好不好喝，除了最基本的幾個要素，更深入的部分，其實我認為沒有標準答案，因此我會用我認為的標準答案，去評斷LLM模型的回答。

# %% [markdown]
# # 4. 比較模型 :
# ### **ChatGPT4.0**   VS   **Claude3.7**

# %% [markdown]
# # 5. 心得:
# ### 整體看下來，GPT在以下幾點是勝過Claude3.7的
#
#
#
#
# ###1.   **使用體驗 :**  會用比較像人類在聊天的方式回答還會有圖案符號等，誘發想繼續閱讀的興致。
#
#
#
# ###2.   **可讀性 :**  只要是多個可比較的項目，GPT都會自動整理成表格方便比較。
#
#
#
# ###3.   **精準回答 :**  除了整體正確性較高外，我的prompts沒有特別輸入與台灣相關的字眼，但他給我的資料，都會是以台灣茶相關的資料回答，但claude就不一定，會以全世界或中國茶為基礎回答。

# %% [markdown]
# # 6.比較內容重點摘要
#
#
# ##6-1 當我對回覆內容覺得有錯誤時，提出意見，兩邊的回答如下 :
#
#
# -------------------------------------------------------------------------------
# ##prompt : 紅茶其實不宜沖泡這麼久，導致後續幾泡的茶湯也容易苦澀
# -------------------------------------------------------------------------------
# ## GPT :
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ________________________________________________________________________________
# ## claude :
#
#
# ![image.png](data:image/png;base64,...)
#
# --------------------------------------------------------------------------------
#
#
# ##個人觀點 :
#
# ##因為這部分就我實際測試經驗，以及所學習的知識其實是45秒~1分左右，
#
# ##通常我都抓1分鐘再依據水溫加減秒數，然而他們一開始都說3~4分鐘，當我跟他們糾正後，
#
#
# ##GPT就有馬上修正，舉例時還提到台茶18號，但Claude還是沒有修正，回答只照世界或中國的紅茶種類進行說明。

# %% [markdown]
# # 6-2 可視化比較
# -------------------------------------------------------------------------------
# ##prompt : 茶器的材質選擇，哪種茶葉是何種哪種材質
# -------------------------------------------------------------------------------
# ##GPT :
# ![image.png](data:image/png;base64,...)
#
# _______________________________________________________________________________
#
# ##Claude :
# ![image.png](data:image/png;base64,...)
#
#
# --------------------------------------------------------------------------------
# ##個人觀點 : 我認為回答內容雖然差不多，重點都有講到，但GPT的可讀性更優。
# -------------------------------------------------------------------------------

# %% [markdown]
# ##6-3 內容回答的廣度
# --------------------------------------------------------------------------------
# ##prompt : 青心烏龍是甚麼
# --------------------------------------------------------------------------------
# ##GPT:
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# --------------------------------------------------------------------------------
# ## claude:
# ![image.png](data:image/png;base64,...)
#
# --------------------------------------------------------------------------------
# ## 個人觀點 : GPT還有另外將其他茶樹種一起做比較，有助於觸類旁通，回答的廣度較廣。
# --------------------------------------------------------------------------------
